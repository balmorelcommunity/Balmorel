# %% [markdown]
# # Import Required Packages

# %%
# Imports
import os
import datetime
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Input data from User

# %%
#Market analysed: 'Investment','FullYear','DayAhead','Balancing' (choose one or several)
markets=['DayAhead'] 
output='ProductionHourly'
first_timestep="2012-01-02"
#Meaning of SSS and TTT in the data: 'DaysHours','Hours5min','WeeksHours'
meaning_SSS_TTT='DaysHours'
#Time size of each time step in TTT for creating timestamp
size_timestep="3600s"

# %% [markdown]
# # Plot Settings

# %%
# Set plotting specifications
# %matplotlib inline
plt.rcParams.update({'font.size': 21})
plt.rcParams['xtick.major.pad']='12'
plt.rc('legend', fontsize=16)
y_limit = 1.1
lw = 3

# %% [markdown]
# # Read Input Files

# %%
data=pd.DataFrame()
for market in markets:
    csvfiles = []
    for file in glob.glob("./input/results/" + market + "/*.csv"):
        csvfiles.append(file)

    csvfiles=[file.replace('./input\\','') for file in csvfiles] 
    csvfiles=[file.replace('.csv','') for file in csvfiles]  
    csvfiles=[file.split('_') for file in csvfiles]  
    csvfiles = np.asarray(csvfiles)  
    csvfiles=pd.DataFrame.from_records(csvfiles)
    
    csvfiles.rename(columns={0: 'Output', 1: 'Scenario',2: 'Year',3:'Subset'}, inplace=True)
    scenarios=csvfiles.Scenario.unique().tolist()
    years=csvfiles.Year.unique().tolist()
    subsets=csvfiles.Subset.unique().tolist()

    for scenario in scenarios:
        for year in years:
            for subset in subsets:
                file = "./input/results/"+ market + "/"+ output + "_" + scenario + "_" + year + "_" + subset + ".csv"
                if os.path.isfile(file):
                    df=pd.read_csv(file,encoding='utf8')
                    df['Scenario'] = scenario
                    df['Market']   = market
                    #Renaming columns just in case timeconversion was required
                    df.rename(columns = {'G':'GGG', 'C':'CCC', 'Y':'YYY','TTT_NEW':'TTT','SSS_NEW':'SSS'}, inplace = True) 
                    data=data.append(df)

# %%
#Timestamp addition
full_timesteps = pd.read_csv('./input/full_timesteps_'+meaning_SSS_TTT+'.csv')
full_timesteps.Key=full_timesteps['SSS']+full_timesteps['TTT']
number_periods=len(full_timesteps.Key.unique())
full_timesteps['timestamp']= pd.date_range(first_timestep, periods = number_periods, freq =size_timestep)
dict_timestamp=dict(zip(full_timesteps.Key, full_timesteps.timestamp))
data['timestamp']=data['SSS']+data['TTT']
data['timestamp']=data['timestamp'].map(dict_timestamp)
# Out:
# C:\Users\s151529\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Additional set declaration

# %%
ccc = list(data.CCC.unique())
rrr = list(data.RRR.unique())
tech_type = list(data.TECH_TYPE.unique())
commodity = list(data.COMMODITY.unique())
fff = list(data.FFF.unique())
sss = list(full_timesteps.SSS.unique())
ttt = list(full_timesteps.TTT.unique())

# %% [markdown]
# # Time step selection

# %%
# Seasons to investigate
# season_names = ['S01', 'S07', 'S20', 'S24', 'S28', 'S38', 'S42', 'S43']
# Make a list of every nth element of sss (1 <= nth <= number of elements in sss)
nth = 1
s = sss[0::nth]
 # Or select seasons by names
# s = season_names

# %%
# Terms to investigate
# term_names = ['T005', 'T019', 'T033', 'T047', 'T061', 'T075', 'T089', 'T103', 'T117', 'T131', 'T145', 'T159']
# Make a list of every nth element of ttt (1 <= nth <= number of elements in ttt)
nth = 1
t = ttt[0::nth]
# Or select terms by name
# t = term_names

# %% [markdown]
# # Make Directories

# %%
# Make output folder
if not os.path.isdir('output'):
    os.makedirs('output')

# %%
# Make CurtailmentHourly folder
if not os.path.isdir('output/' + output):
    os.makedirs('output/' + output)

# %%
# Make market folder
for market in markets:
    if not os.path.isdir('output/' + output + '/'+ market +'/Country_wise'):
        os.makedirs('output/' + output + '/'+ market +'/Country_wise')
# Make country folder
    if not os.path.isdir('output/' + output  + '/'+ market +'/Country_wise'):
        os.makedirs('output/' + output  + '/'+ market  +'/Country_wise')
    # Make country wise folders
    for c in ccc:
        if not os.path.isdir('output/' + output  + '/'+ market +'/Country_wise/' + c):
            os.makedirs('output/' + output  + '/'+ market +'/Country_wise/' + c)

# %% [markdown]
# # Plotting

# %% [markdown]
# ##  Data export

# %%
data
# Out:
#           YYY     CCC  RRR           AAA  \
# 0        2045  NORWAY  NO1        NO1_A1
# 1        2045  NORWAY  NO1        NO1_A1
# 2        2045  NORWAY  NO1        NO1_A1
# 3        2045  NORWAY  NO1        NO1_A1
# 4        2045  NORWAY  NO1        NO1_A1
# 5        2045  NORWAY  NO1        NO1_A1
# 6        2045  NORWAY  NO1        NO1_A1
# 7        2045  NORWAY  NO1        NO1_A1
# 8        2045  NORWAY  NO1        NO1_A1
# 9        2045  NORWAY  NO1        NO1_A1
# 10       2045  NORWAY  NO1        NO1_A1
# 11       2045  NORWAY  NO1        NO1_A1
# 12       2045  NORWAY  NO1        NO1_A1
# 13       2045  NORWAY  NO1        NO1_A1
# 14       2045  NORWAY  NO1        NO1_A1
# 15       2045  NORWAY  NO1        NO1_A1
# 16       2045  NORWAY  NO1        NO1_A1
# 17       2045  NORWAY  NO1        NO1_A1
# 18       2045  NORWAY  NO1        NO1_A1
# 19       2045  NORWAY  NO1        NO1_A1
# 20       2045  NORWAY  NO1        NO1_A1
# 21       2045  NORWAY  NO1        NO1_A1
# 22       2045  NORWAY  NO1        NO1_A1
# 23       2045  NORWAY  NO1        NO1_A1
# 24       2045  NORWAY  NO1        NO1_A1
# 25       2045  NORWAY  NO1        NO1_A1
# 26       2045  NORWAY  NO1        NO1_A1
# 27       2045  NORWAY  NO1        NO1_A1
# 28       2045  NORWAY  NO1        NO1_A1
# 29       2045  NORWAY  NO1        NO1_A1
# ...       ...     ...  ...           ...
# 6991981  2045  FRANCE   FR  FR_IND-MT-DH
# 6991982  2045  FRANCE   FR  FR_IND-MT-DH
# 6991983  2045  FRANCE   FR  FR_IND-MT-DH
# 6991984  2045  FRANCE   FR  FR_IND-MT-DH
# 6991985  2045  FRANCE   FR  FR_IND-MT-DH
# 6991986  2045  FRANCE   FR  FR_IND-MT-DH
# 6991987  2045  FRANCE   FR  FR_IND-MT-DH
# 6991988  2045  FRANCE   FR  FR_IND-MT-DH
# 6991989  2045  FRANCE   FR  FR_IND-MT-DH
# 6991990  2045  FRANCE   FR  FR_IND-MT-DH
# 6991991  2045  FRANCE   FR  FR_IND-MT-DH
# 6991992  2045  FRANCE   FR  FR_IND-MT-DH
# 6991993  2045  FRANCE   FR  FR_IND-MT-DH
# 6991994  2045  FRANCE   FR  FR_IND-MT-DH
# 6991995  2045  FRANCE   FR  FR_IND-MT-DH
# 6991996  2045  FRANCE   FR  FR_IND-MT-DH
# 6991997  2045  FRANCE   FR  FR_IND-MT-DH
# 6991998  2045  FRANCE   FR  FR_IND-MT-DH
# 6991999  2045  FRANCE   FR  FR_IND-MT-DH
# 6992000  2045  FRANCE   FR  FR_IND-MT-DH
# 6992001  2045  FRANCE   FR  FR_IND-MT-DH
# 6992002  2045  FRANCE   FR  FR_IND-MT-DH
# 6992003  2045  FRANCE   FR  FR_IND-MT-DH
# 6992004  2045  FRANCE   FR  FR_IND-MT-DH
# 6992005  2045  FRANCE   FR  FR_IND-MT-DH
# 6992006  2045  FRANCE   FR  FR_IND-MT-DH
# 6992007  2045  FRANCE   FR  FR_IND-MT-DH
# 6992008  2045  FRANCE   FR  FR_IND-MT-DH
# 6992009  2045  FRANCE   FR  FR_IND-MT-DH
# 6992010  2045  FRANCE   FR  FR_IND-MT-DH
#
#                                                  GGG        FFF   SSS  TTT  \
# 0                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T01
# 1                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T02
# 2                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T03
# 3                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T04
# 4                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T05
# 5                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T06
# 6                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T07
# 7                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T08
# 8                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T09
# 9                            GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T10
# 10                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T11
# 11                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T12
# 12                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T13
# 13                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T14
# 14                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T15
# 15                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T16
# 16                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T17
# 17                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T18
# 18                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T19
# 19                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T20
# 20                           GNR_RES_WTR_NOPMP_MC-01      WATER  S001  T21
# 21                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T01
# 22                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T02
# 23                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T03
# 24                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T04
# 25                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T05
# 26                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T06
# 27                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T07
# 28                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T08
# 29                           GNR_RES_WTR_NOPMP_MC-01      WATER  S004  T09
# ...                                              ...        ...   ...  ...
# 6991981  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T10
# 6991982  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T10
# 6991983  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T11
# 6991984  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T11
# 6991985  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T12
# 6991986  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T12
# 6991987  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T13
# 6991988  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T13
# 6991989  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T14
# 6991990  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T14
# 6991991  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T15
# 6991992  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T15
# 6991993  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T16
# 6991994  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T16
# 6991995  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T17
# 6991996  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T17
# 6991997  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T18
# 6991998  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T18
# 6991999  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T19
# 6992000  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T19
# 6992001  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T20
# 6992002  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T20
# 6992003  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T21
# 6992004  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T21
# 6992005  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T22
# 6992006  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T22
# 6992007  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T23
# 6992008  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T23
# 6992009  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T24
# 6992010  GNR_ST_WOODCHI_BP_E-16_SS-20-MW-FEED_Y-2020  WOODCHIPS  S355  T24
#
#            COMMODITY          TECH_TYPE UNITS         Val Scenario    Market  \
# 0        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 1        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 2        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 3        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 4        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 5        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 6        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 7        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 8        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 9        ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 10       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 11       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 12       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 13       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 14       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 15       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 16       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 17       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 18       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 19       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 20       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 21       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 22       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 23       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 24       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 25       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 26       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 27       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 28       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# 29       ELECTRICITY   HYDRO-RESERVOIRS   MWh  200.000000     Base  DayAhead
# ...              ...                ...   ...         ...      ...       ...
# 6991981         HEAT  CHP-BACK-PRESSURE   MWh  140.907712     Base  DayAhead
# 6991982  ELECTRICITY  CHP-BACK-PRESSURE   MWh   22.545234     Base  DayAhead
# 6991983         HEAT  CHP-BACK-PRESSURE   MWh  143.887375     Base  DayAhead
# 6991984  ELECTRICITY  CHP-BACK-PRESSURE   MWh   21.521821     Base  DayAhead
# 6991985         HEAT  CHP-BACK-PRESSURE   MWh  141.765169     Base  DayAhead
# 6991986  ELECTRICITY  CHP-BACK-PRESSURE   MWh   22.682427     Base  DayAhead
# 6991987         HEAT  CHP-BACK-PRESSURE   MWh  118.999691     Base  DayAhead
# 6991988  ELECTRICITY  CHP-BACK-PRESSURE   MWh   19.039951     Base  DayAhead
# 6991989         HEAT  CHP-BACK-PRESSURE   MWh   91.732565     Base  DayAhead
# 6991990  ELECTRICITY  CHP-BACK-PRESSURE   MWh   14.677210     Base  DayAhead
# 6991991         HEAT  CHP-BACK-PRESSURE   MWh   81.464520     Base  DayAhead
# 6991992  ELECTRICITY  CHP-BACK-PRESSURE   MWh   13.034323     Base  DayAhead
# 6991993         HEAT  CHP-BACK-PRESSURE   MWh   67.166428     Base  DayAhead
# 6991994  ELECTRICITY  CHP-BACK-PRESSURE   MWh   10.746628     Base  DayAhead
# 6991995         HEAT  CHP-BACK-PRESSURE   MWh   61.485776     Base  DayAhead
# 6991996  ELECTRICITY  CHP-BACK-PRESSURE   MWh    9.837724     Base  DayAhead
# 6991997         HEAT  CHP-BACK-PRESSURE   MWh   53.147009     Base  DayAhead
# 6991998  ELECTRICITY  CHP-BACK-PRESSURE   MWh    8.503521     Base  DayAhead
# 6991999         HEAT  CHP-BACK-PRESSURE   MWh   46.930447     Base  DayAhead
# 6992000  ELECTRICITY  CHP-BACK-PRESSURE   MWh    7.508872     Base  DayAhead
# 6992001         HEAT  CHP-BACK-PRESSURE   MWh   36.769584     Base  DayAhead
# 6992002  ELECTRICITY  CHP-BACK-PRESSURE   MWh    5.883133     Base  DayAhead
# 6992003         HEAT  CHP-BACK-PRESSURE   MWh   35.912127     Base  DayAhead
# 6992004  ELECTRICITY  CHP-BACK-PRESSURE   MWh    5.745940     Base  DayAhead
# 6992005         HEAT  CHP-BACK-PRESSURE   MWh   35.311907     Base  DayAhead
# 6992006  ELECTRICITY  CHP-BACK-PRESSURE   MWh    5.649905     Base  DayAhead
# 6992007         HEAT  CHP-BACK-PRESSURE   MWh   33.961413     Base  DayAhead
# 6992008  ELECTRICITY  CHP-BACK-PRESSURE   MWh    5.433826     Base  DayAhead
# 6992009         HEAT  CHP-BACK-PRESSURE   MWh   30.231476     Base  DayAhead
# 6992010  ELECTRICITY  CHP-BACK-PRESSURE   MWh    4.837036     Base  DayAhead
#
#                   timestamp
# 0       2012-01-02 00:00:00
# 1       2012-01-02 01:00:00
# 2       2012-01-02 02:00:00
# 3       2012-01-02 03:00:00
# 4       2012-01-02 04:00:00
# 5       2012-01-02 05:00:00
# 6       2012-01-02 06:00:00
# 7       2012-01-02 07:00:00
# 8       2012-01-02 08:00:00
# 9       2012-01-02 09:00:00
# 10      2012-01-02 10:00:00
# 11      2012-01-02 11:00:00
# 12      2012-01-02 12:00:00
# 13      2012-01-02 13:00:00
# 14      2012-01-02 14:00:00
# 15      2012-01-02 15:00:00
# 16      2012-01-02 16:00:00
# 17      2012-01-02 17:00:00
# 18      2012-01-02 18:00:00
# 19      2012-01-02 19:00:00
# 20      2012-01-02 20:00:00
# 21      2012-01-05 00:00:00
# 22      2012-01-05 01:00:00
# 23      2012-01-05 02:00:00
# 24      2012-01-05 03:00:00
# 25      2012-01-05 04:00:00
# 26      2012-01-05 05:00:00
# 27      2012-01-05 06:00:00
# 28      2012-01-05 07:00:00
# 29      2012-01-05 08:00:00
# ...                     ...
# 6991981 2012-12-21 09:00:00
# 6991982 2012-12-21 09:00:00
# 6991983 2012-12-21 10:00:00
# 6991984 2012-12-21 10:00:00
# 6991985 2012-12-21 11:00:00
# 6991986 2012-12-21 11:00:00
# 6991987 2012-12-21 12:00:00
# 6991988 2012-12-21 12:00:00
# 6991989 2012-12-21 13:00:00
# 6991990 2012-12-21 13:00:00
# 6991991 2012-12-21 14:00:00
# 6991992 2012-12-21 14:00:00
# 6991993 2012-12-21 15:00:00
# 6991994 2012-12-21 15:00:00
# 6991995 2012-12-21 16:00:00
# 6991996 2012-12-21 16:00:00
# 6991997 2012-12-21 17:00:00
# 6991998 2012-12-21 17:00:00
# 6991999 2012-12-21 18:00:00
# 6992000 2012-12-21 18:00:00
# 6992001 2012-12-21 19:00:00
# 6992002 2012-12-21 19:00:00
# 6992003 2012-12-21 20:00:00
# 6992004 2012-12-21 20:00:00
# 6992005 2012-12-21 21:00:00
# 6992006 2012-12-21 21:00:00
# 6992007 2012-12-21 22:00:00
# 6992008 2012-12-21 22:00:00
# 6992009 2012-12-21 23:00:00
# 6992010 2012-12-21 23:00:00
#
# [6992011 rows x 15 columns]

# %%
table = pd.pivot_table(data[(data.TECH_TYPE == 'WIND-ON')], values='Val', index=['Market','Scenario','YYY','timestamp'],
...                     columns=['AAA'], aggfunc=np.sum, fill_value=0).reset_index()

# %%
for market in markets:
    for scenario in scenarios:
        for year in years:
                table_export=table[table.columns.difference(['Market','Scenario','YYY'])].loc[(table['Market'] == market) & (table['Scenario'] == scenario) &  (table['YYY'].astype(str) == year)]
                table_export=table_export.set_index(['timestamp'])
                table_export.to_csv('Output/'+output+'/'+output+'_'+market+'_'+scenario+'_'+year+'.csv')
