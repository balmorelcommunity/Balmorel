# %%
from pybalmorel import MainResults

f = MainResults('MainResults_firsttests.gdx', paths='.')
f.interactive_bar_chart()
# Out:
# c:\Users\mberos\gitRepos\Balmorel\new_muni\model\MainResults_firsttests.gdx
# GridBox(children=(Dropdown(description='Table:', layout=Layout(width='80%'), options=('F_CONS_YCRA', 'F_CONS_Y…
# Output()
# Stack(children=(GridBox(children=(SelectMultiple(description='Scenario', index=(0,), layout=Layout(height='99%…
# Output()
# ...
# Output()
# HBox()
# Output()
# ...
# Output()
# Output()

# %%
f.plot_profile('electricity', 2050)
# Out:
# (<Figure size 900x300 with 2 Axes>,
#  <Axes: title={'center': 'firsttests - ELECTRICITY - All - 2050'}, ylabel='Power [GW]'>)

# %%
fig, ax = f.plot_map('firsttests', 'Hydrogen', 2050, path_to_geofile=r'C:\Users\mberos\gitRepos\balmorel-preprocessing\src\dkmun_indname.gpkg')
ax.set_xlim(7, 16)
ax.set_ylim(54.5, 58)
# Out:
# Found MainResults in .\MainResults_firsttests.gdx
